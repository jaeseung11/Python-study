# %%
# for문으로 최대값 구하는 알고리즘.
num_list = [1,2,3,6,2,4,5,80]

max = 0
for num in num_list:
    if max < num:
        print(max)  # 여기서 max는 num보다 작을때 출력된다.
        max = num   # max 변수을 num의 데이터로 집어넣는다.
  
print(max)
# Out:
# 0
# 1
# 2
# 3
# 6
# 80
